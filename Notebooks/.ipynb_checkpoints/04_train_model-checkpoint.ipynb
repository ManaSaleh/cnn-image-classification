# %% [markdown]
# ### **Step 1: Load and Split the Data Using `ImageDataGenerator`**
#
# We’ll use `ImageDataGenerator` to split the cat and dog dataset into training and validation sets.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import numpy as np
import random

# Set random seeds for reproducibility
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
# Initialize ImageDataGenerator for splitting and rescaling
data_gen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    validation_split=0.2  # Reserve 20% for validation
)

# %%
# Training data generator
train_generator = data_gen.flow_from_directory(
    '../animals/',  # Path to training data
    target_size=(150, 150),  # Resize images to (150x150)
    batch_size=32,  # Number of images per batch
    class_mode='binary',  # Binary classification (cat vs. dog)
    subset='training'  # Use the training portion
)
# Out:
# Found 800 images belonging to 2 classes.

# %%
# Ensure validation generator does not shuffle data
validation_generator = data_gen.flow_from_directory(
    '../animals/',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='validation',
    shuffle=False  # Ensure no shuffling
)
# Out:
# Found 200 images belonging to 2 classes.

# %% [markdown]
# 1. **Data Rescaling:**
#    - `rescale=1.0/255` normalizes pixel values to `[0, 1]`.
#
# 2. **Data Splitting:**
#    - `validation_split=0.2`: Reserves 20% of the training dataset for validation.
#
# 3. **Training and Validation Generators:**
#    - `train_generator`: Loads and processes the training portion.
#    - `validation_generator`: Loads and processes the validation portion.
#
# 4. **Parameters:**
#    - `target_size=(150, 150)`: Resizes images to fit the model input.
#    - `batch_size=32`: Specifies the number of images processed per batch.
#    - `class_mode='binary'`: Specifies binary classification for cats and dogs.
#
# ---

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

# %%
# Initialize the CNN model
model = Sequential([
    # Input Layer
    Input(shape=(150, 150, 3)),

    # Convolutional and Pooling Layers
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    # Flatten and Fully Connected Layers
    Flatten(),
    Dense(128, activation='relu'),

    # Output Layer
    Dense(1, activation='sigmoid')
])

# Print Model Summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     4,735,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,828,481 (18.42 MB)
#  Trainable params: 4,828,481 (18.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 1. **Model Initialization:**
#    - We create a CNN using `Sequential` and define layers in a list.
#
# 2. **Convolutional Layers:**
#    - `Conv2D(filters, kernel_size, activation)` extracts features.
#    - `MaxPooling2D(pool_size)` reduces spatial dimensions.
#
# 3. **Fully Connected Layer:**
#    - `Dense(units, activation)` processes features before output.
#
# 4. **Output Layer:**
#    - `Dense(1, activation='sigmoid')` outputs a probability for binary classification.

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ---

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=10,  
    validation_data=validation_generator
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - accuracy: 0.5196 - loss: 1.0741 - val_accuracy: 0.5700 - val_loss: 0.6307
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.7541 - loss: 0.5378 - val_accuracy: 0.8050 - val_loss: 0.4468
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.8680 - loss: 0.3427 - val_accuracy: 0.8500 - val_loss: 0.3725
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9054 - loss: 0.2815 - val_accuracy: 0.9200 - val_loss: 0.2317
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9493 - loss: 0.1447 - val_accuracy: 0.8900 - val_loss: 0.2045
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9640 - loss: 0.1201 - val_accuracy: 0.9000 - val_loss: 0.2769
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9765 - loss: 0.0769 - val_accuracy: 0.9400 - val_loss: 0.1414
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9881 - loss: 0.0457 - val_accuracy: 0.9450 - val_loss: 0.1171
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9997 - loss: 0.0131 - val_accuracy: 0.9600 - val_loss: 0.1299
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9550 - val_loss: 0.1044

# %% [markdown]
# ---

# %% [markdown]
# The next step is **Model Evaluation and Visualization.**
#
# We will:
# 1. Evaluate the model’s performance on the validation set.
# 2. Visualize training and validation accuracy/loss over epochs.
# 3. Display some predictions on test images.

# %% [markdown]
# ---

# %% [markdown]
# ### **Step 1: Evaluate the Model**

# %%
# Evaluate the model on validation data
val_loss, val_accuracy = model.evaluate(validation_generator)

print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
print(f"Validation Loss: {val_loss:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9451 - loss: 0.1210
# Validation Accuracy: 95.50%
# Validation Loss: 0.1044

# %% [markdown]
# - `model.evaluate(validation_generator)` returns validation loss and accuracy.
#
# ---

# %% [markdown]
# ### **Step 2: Visualize Training and Validation Performance**

# %%
# Extract training history
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(train_acc) + 1)

# %%
import matplotlib.pyplot as plt

# %%
# Plot accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows the **Training Loss** (blue line) and **Validation Loss** (orange line) over 10 epochs. Let’s break it down:
#
# 1. **Training Loss:**
#    - The blue line decreases consistently and approaches **0** by the 10th epoch.
#    - This indicates that the model is learning very well on the training data.
#
# 2. **Validation Loss:**
#    - The orange line decreases initially but plateaus around **epoch 5** and even slightly increases after that.
#    - This shows the model's performance on unseen (validation) data stops improving.
#
# ---
#
# ### **Indication of Overfitting**
# Overfitting occurs when the model performs very well on the training data but poorly on the validation data.
# In this case:
# - The **training loss continues to decrease**, reaching near zero.
# - The **validation loss stops improving** and remains higher.
#
# This suggests the model has started to **memorize the training data** instead of generalizing well to unseen data.
#
# ---
#
# ### **How to Fix Overfitting**
# 1. **Add Regularization:** Use techniques like L2 regularization or dropout layers.
# 2. **Data Augmentation:** Generate more varied training data.
# 3. **Reduce Model Complexity:** Simplify the architecture (fewer layers or parameters).
# 4. **Early Stopping:** Stop training when the validation loss stops decreasing.
#
# ---

# %% [markdown]
# Let's proceed step by step to address **overfitting** using:
# 1. **Regularization**
# 2. **Reduce Model Complexity with Dropout**
# 3. **Implement Early Stopping**
# 4. **Data Augmentation**

# %% [markdown]
# ### **Step 1: Add Regularization and Dropout**
#
# We’ll add L2 regularization to the convolutional and dense layers, and introduce dropout to randomly deactivate neurons, helping prevent overfitting.

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout

# %%
model = Sequential([
    Input(shape=(150, 150, 3)),

    # First Convolutional Block with Regularization
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    MaxPooling2D((2, 2)),

    # Second Convolutional Block
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    MaxPooling2D((2, 2)),

    # Third Convolutional Block
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    MaxPooling2D((2, 2)),

    # Flatten and Fully Connected Layers with Dropout
    Flatten(),
    Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),  # Drop 50% of neurons

    # Output Layer
    Dense(1, activation='sigmoid')
])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │    18,940,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,034,177 (72.61 MB)
#  Trainable params: 19,034,177 (72.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### **Step 2: Add Early Stopping**
#
# We’ll stop training automatically if the validation loss does not improve for a set number of epochs.

# %%
# Initialize EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=3,          # Stop after 3 epochs with no improvement
    restore_best_weights=True  # Restore the best model weights
)

# %%
# Initialize ImageDataGenerator with data augmentation
train_augmented_gen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    rotation_range=40,  # Random rotation
    width_shift_range=0.2,  # Horizontal shift
    height_shift_range=0.2,  # Vertical shift
    shear_range=0.2,  # Shear transformation
    zoom_range=0.2,  # Zoom in/out
    horizontal_flip=True,  # Flip images horizontally
    fill_mode='nearest'  # Fill missing pixels
)

# %%
# Load augmented training data
train_augmented_generator = train_augmented_gen.flow_from_directory(
    '../animals/', 
    target_size=(150, 150), 
    batch_size=32, 
    class_mode='binary', 
    subset='training'
)
# Out:
# Found 1000 images belonging to 2 classes.

# %%
# Train the model with Early Stopping
history = model.fit(
    train_augmented_generator,
    epochs=50,  # Train for up to 20 epochs
    validation_data=validation_generator,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5769 - loss: 1.6051
# /home/mana-saleh/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 371ms/step - accuracy: 0.5777 - loss: 1.5945 - val_accuracy: 0.7200 - val_loss: 0.9051
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.7033 - loss: 0.8610 - val_accuracy: 0.7600 - val_loss: 0.6710
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step - accuracy: 0.7528 - loss: 0.6933 - val_accuracy: 0.9100 - val_loss: 0.5401
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.8118 - loss: 0.6039 - val_accuracy: 0.9550 - val_loss: 0.4171
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.8664 - loss: 0.5107 - val_accuracy: 0.8100 - val_loss: 0.5368
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.8483 - loss: 0.5333 - val_accuracy: 0.9600 - val_loss: 0.2722
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.9084 - loss: 0.4164 - val_accuracy: 0.9800 - val_loss: 0.2320
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 0.9039 - loss: 0.3820 - val_accuracy: 0.9800 - val_loss: 0.2839
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.9403 - loss: 0.3458 - val_accuracy: 0.9750 - val_loss: 0.2327
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 0.9341 - loss: 0.3480 - val_accuracy: 0.9800 - val_loss: 0.2012
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.9414 - loss: 0.2946 - val_accuracy: 0.9850 - val_loss: 0.1798
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9465 - loss: 0.2877 - val_accuracy: 0.9900 - val_loss: 0.1715
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.9685 - loss: 0.2360 - val_accuracy: 0.9450 - val_loss: 0.2572
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9505 - loss: 0.2811 - val_accuracy: 0.9900 - val_loss: 0.1720
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.9567 - loss: 0.2613 - val_accuracy: 0.9900 - val_loss: 0.1667
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9567 - loss: 0.2682 - val_accuracy: 0.9850 - val_loss: 0.1743
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.9370 - loss: 0.2844 - val_accuracy: 0.9950 - val_loss: 0.1622
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.9774 - loss: 0.2095 - val_accuracy: 0.9900 - val_loss: 0.1470
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 276ms/step - accuracy: 0.9621 - loss: 0.2143 - val_accuracy: 0.9900 - val_loss: 0.1438
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 276ms/step - accuracy: 0.9754 - loss: 0.1990 - val_accuracy: 0.9950 - val_loss: 0.1410
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.9697 - loss: 0.2136 - val_accuracy: 0.9900 - val_loss: 0.1665
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9303 - loss: 0.3112 - val_accuracy: 0.9800 - val_loss: 0.1709
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.9765 - loss: 0.2159 - val_accuracy: 0.9950 - val_loss: 0.1452

# %% [markdown]
# 1. **L2 Regularization:** Adds a penalty to large weights, discouraging overfitting.
#    - `kernel_regularizer=regularizers.l2(0.001)` penalizes large weights.
#
# 2. **Dropout Layer:**
#    - `Dropout(0.5)` randomly deactivates 50% of neurons during training to improve generalization.
#
# 3. **Early Stopping:**
#    - Monitors `val_loss` and stops training when it stops improving for 3 epochs.
#    - `restore_best_weights=True` ensures the model reverts to the best-performing epoch.
#
# ---

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(validation_generator)

print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
print(f"Validation Loss: {val_loss:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9981 - loss: 0.1438
# Validation Accuracy: 99.50%
# Validation Loss: 0.1410

# %%
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(train_acc) + 1)

# %%
# Plot Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title("Training and Validation Loss After Regularization & Dropout")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 1. **Validation Loss Trend**:
#    - Compared to the earlier plot, the **validation loss** should now decrease more steadily.
#    - The gap between **training loss** and **validation loss** should have **reduced** slightly, indicating better generalization.
#
# 2. **Effect of Dropout**:
#    - By dropping 50% of neurons randomly in the dense layer, the model learns to generalize instead of relying heavily on specific neurons. This reduces overfitting.
#
# 3. **Effect of L2 Regularization**:
#    - L2 regularization penalized large weights, which helps prevent the model from becoming too complex and overfitting the training data.
#
# 4. **Early Stopping**:
#    - Training stopped automatically when the validation loss stopped improving, preventing the model from overfitting due to excessive training.
#
# ---

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score, f1_score

# %%
# Get true labels and predictions
true_labels = validation_generator.classes
predictions = model.predict(validation_generator)
predicted_labels = np.round(predictions).flatten()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step

# %%
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

# %%
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 99.50%
# F1 Score: 0.9950

# %%
# Print detailed classification report
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels, target_names=['Cat', 'Dog']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          Cat       0.99      1.00      1.00       100
#          Dog       1.00      0.99      0.99       100
#
#     accuracy                           0.99       200
#    macro avg       1.00      0.99      0.99       200
# weighted avg       1.00      0.99      0.99       200

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Cat', 'Dog'])

# %%
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix for Cats and Dogs")
plt.show();
